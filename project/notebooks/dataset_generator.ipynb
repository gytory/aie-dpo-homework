# %% [markdown]
# # Создание датасета
#
# В данном ноутбуке представлено создание синтетических данных для анализа и экспериментов.
#
# Всего представлено 40 ответов технической поддержким онлайн курсов и 150 запросов с разным содержанием.
#
# В ответах выдержан деловой стиль и типичные для техподдержки ображения. В запросах представлены разные варианты обращений, включающие деловые обращения, неформальные, также включены различные опечатки и сленг.

# %% [markdown]
# ## Текст ответов и запросов

# %% [markdown]
# Ответы распределены по темам обращений для ускорения оценки попадания в тему запроса.
#
# В запросах заранее прописаны номера релевантных ответов.

# %%
documents = [
    ["doc_1", "Авторизация", "Здравствуйте! Благодарим за обращение в нашу службу поддержки. Для сброса пароля перейдите на страницу входа и нажмите 'Забыли пароль'. Ссылка для восстановления придёт на вашу электронную почту в течение 5 минут. Если письмо не пришло, проверьте папку 'Спам'."],
    ["doc_2", "Авторизация", "Добрый день! Спасибо, что обратились к нам. Восстановление доступа к аккаунту производится через форму 'Забыли пароль'. Также вы можете отправить запрос в поддержку с указанием email, на который зарегистрирован аккаунт. Обычно это занимает не более 10 минут."],
    ["doc_3", "Авторизация", "Здравствуйте! Мы получили ваш вопрос. Для входа в личный кабинет используйте email и пароль, указанные при регистрации. Если вы забыли пароль, нажмите кнопку 'Забыли пароль' на странице входа. Ссылка для восстановления будет активна 24 часа."],
    ["doc_4", "Авторизация", "Приветствуем вас! Спасибо за обращение. Проблемы со входом могут быть связаны с неверным паролем. Рекомендуем сбросить его через форму восстановления. Если ничего не помогает, напишите нам с вашей почты, и мы отправим ссылку для входа вручную."],
    ["doc_5", "Авторизация", "Добрый день! Благодарим за вопрос. Если вы не можете войти, проверьте правильность раскладки клавиатуры и Caps Lock. Для сброса пароля используйте кнопку 'Забыли пароль'. Новая ссылка придёт на вашу почту в течение нескольких минут."],
    ["doc_6", "Авторизация", "Здравствуйте! Спасибо, что выбрали нашу платформу. Для восстановления доступа к аккаунту, пожалуйста, перейдите по ссылке 'Забыли пароль' на странице входа. После смены пароля вы сможете войти без проблем. Мы всегда готовы помочь!"],
    ["doc_7", "Авторизация", "Приветствуем! Рады вашему обращению. Если вы не получаете письмо для сброса пароля, добавьте наш домен в белый список вашего почтового ящика. Также проверьте папку 'Спам' и 'Рассылки'. В крайнем случае, свяжитесь с нами через форму обратной связи."],
    ["doc_8", "Авторизация", "Здравствуйте! Благодарим за обращение в техподдержку. Для ускорения процесса восстановления пароля, пожалуйста, укажите в ответном письме ваш логин или email, на который зарегистрирован аккаунт. Мы отправим ссылку в течение часа."],
    
    ["doc_9", "Оплата", "Здравствуйте! Спасибо за обращение. Оплата обучения производится банковской картой, через СБП или по счёту для юридических лиц. Ссылка на оплату доступна в личном кабинете после выбора курса. Если возникли трудности, напишите нам!"],
    ["doc_10", "Оплата", "Добрый день! Благодарим за ваш вопрос. Мы принимаем оплату картами Visa, Mastercard, МИР, а также через мобильных операторов и электронные кошельки. Полный список способов оплаты доступен на странице платежа. Если что-то непонятно, мы поможем."],
    ["doc_11", "Оплата", "Приветствуем! Спасибо, что обратились к нам. Промокод вводится в специальное поле на странице оплаты перед подтверждением платежа. Скидка применяется автоматически. Если промокод не работает, проверьте срок его действия и правильность написания."],
    ["doc_12", "Оплата", "Здравствуйте! Благодарим за обращение. Возврат средств возможен при обращении в течение 7 дней с момента оплаты при условии, что вы не начали обучение. Для оформления возврата заполните форму в разделе 'Финансы' → 'Возврат'."],
    ["doc_13", "Оплата", "Добрый день! Спасибо за ваш вопрос. Ошибка при оплате обычно связана с недостатком средств на счёте или блокировкой карты банком. Рекомендуем обратиться в ваш банк для уточнения причины. После устранения проблемы попробуйте снова."],
    ["doc_14", "Оплата", "Здравствуйте! Мы получили ваше сообщение. Задержка зачисления оплаты может составлять до 24 часов в зависимости от банка. Если прошло больше времени, пришлите нам чек или скриншот об успешном списании, и мы проверим статус платежа."],
    ["doc_15", "Оплата", "Приветствуем! Спасибо, что выбрали нашу платформу. Студенческая скидка предоставляется при подтверждении статуса через международную систему удостоверений ISIC. Размер скидки составляет 30%. Для активации свяжитесь с нами после оплаты полной стоимости."],
    ["doc_16", "Оплата", "Добрый день! Благодарим за обращение. Вы можете оплатить обучение частями через сервис 'Долями' или 'Сплит'. Для этого на странице оплаты выберите соответствующий способ. Если у вас возникли вопросы, мы с радостью поможем!"],
    
    ["doc_17", "Сертификат", "Здравствуйте! Спасибо за обращение. Сертификат об обучении выдаётся автоматически после успешного завершения всех модулей и итогового тестирования. Скачать его можно в разделе 'Мои сертификаты' в личном кабинете в формате PDF."],
    ["doc_18", "Сертификат", "Добрый день! Благодарим за вопрос. Для получения сертификата с отличием необходимо набрать средний балл выше 90% по всем тестам и успешно выполнить итоговый проект. Подробные критерии описаны на странице каждого курса. Успехов вам!"],
    ["doc_19", "Сертификат", "Приветствуем! Спасибо, что обратились к нам. Если ваш сертификат не отображается, проверьте, завершены ли все уроки и тесты. Иногда требуется до 24 часов для генерации документа. Если проблема остаётся, напишите нам, и мы проверим ваш прогресс."],
    ["doc_20", "Сертификат", "Здравствуйте! Благодарим за обращение. Электронный сертификат доступен для скачивания в течение года после завершения курса. Если вы потеряли файл, просто зайдите в личный кабинет и скачайте его снова. Мы храним все сертификаты постоянно."],
    ["doc_21", "Сертификат", "Добрый день! Спасибо за ваш вопрос. Если в сертификате обнаружена ошибка (например, неверное имя), пожалуйста, напишите нам с указанием правильных данных. Мы сформируем новый сертификат и отправим вам на почту в течение 3 рабочих дней."],
    ["doc_22", "Сертификат", "Здравствуйте! Мы получили ваше сообщение. Сертификат в бумажном виде можно заказать за дополнительную плату. Для этого заполните форму в разделе 'Сертификаты' → 'Заказать бумажную версию'. Доставка осуществляется Почтой России в течение 14 дней."],
    ["doc_23", "Сертификат", "Приветствуем! Спасибо за обращение. Некоторые курсы предполагают выдачу сертификата государственного образца. Это указано в описании курса. Для получения такого сертификата требуется пройти финальную аттестацию в очном формате или онлайн-прокторинг."],
    ["doc_24", "Сертификат", "Добрый день! Благодарим за вопрос. Сертификат можно скачать на любом устройстве: компьютере, планшете или телефоне. Если файл не открывается, попробуйте обновить страницу или использовать другой браузер. PDF-файлы открываются в любой современной программе."],
    
    ["doc_25", "Домашнее задание", "Здравствуйте! Спасибо за обращение. Загрузка домашних заданий производится в разделе 'Домашние задания' через форму прикрепления файлов. Мы поддерживаем форматы .pdf, .docx, .txt и .jpg. Максимальный размер файла — 50 МБ. Если возникли проблемы, напишите нам!"],
    ["doc_26", "Домашнее задание", "Добрый день! Благодарим за ваш вопрос. Проверка домашних заданий занимает до 3 рабочих дней. Уведомление о результате проверки приходит на вашу электронную почту и в личный кабинет. Если прошло больше времени, пожалуйста, свяжитесь с куратором."],
    ["doc_27", "Домашнее задание", "Приветствуем! Спасибо, что обратились к нам. Если вы получили низкую оценку за домашнее задание, вы можете загрузить исправленную версию. Количество пересдач не ограничено, но учитывается последняя версия. Желаем успехов в обучении!"],
    ["doc_28", "Домашнее задание", "Здравствуйте! Благодарим за обращение. Итоговый проект загружается в специальную форму в последнем модуле курса. Требования к проекту описаны в методических материалах. Рекомендуем ознакомиться с ними перед началом работы над проектом."],
    ["doc_29", "Домашнее задание", "Добрый день! Спасибо за ваш вопрос. Если домашнее задание не загружается, проверьте формат и размер файла. Также попробуйте очистить кэш браузера или использовать другой браузер. Если ничего не помогает, напишите нам, и мы поможем решить проблему."],
    ["doc_30", "Домашнее задание", "Здравствуйте! Мы получили ваше сообщение. Для автоматической проверки тестовых заданий результат приходит мгновенно. Для заданий с открытым ответом проверка выполняется куратором. Обычно это занимает 1-2 дня. Спасибо за ваше терпение!"],
    ["doc_31", "Домашнее задание", "Приветствуем! Спасибо за обращение. Если куратор долго не проверяет домашнее задание, возможно, он находится в отпуске. Напишите нам, и мы передадим ваше задание другому проверяющему. Мы ценим ваше время и стараемся отвечать оперативно."],
    ["doc_32", "Домашнее задание", "Добрый день! Благодарим за вопрос. Рекомендуемый объём итогового проекта — 10-15 страниц. Плагиат проверяется автоматически. Уникальность текста должна быть не менее 70%. Если у вас есть вопросы по оформлению, обратитесь к методическим рекомендациям."],
    
    ["doc_33", "Технические проблемы", "Здравствуйте! Спасибо за обращение. Проблемы с воспроизведением видео могут быть связаны с вашим браузером. Рекомендуем использовать последнюю версию Chrome, Firefox, Edge или Safari. Также попробуйте отключить блокировщики рекламы и очистить кэш."],
    ["doc_34", "Технические проблемы", "Добрый день! Благодарим за вопрос. Если сайт тормозит, проверьте скорость вашего интернет-соединения. Для стабильной работы рекомендуем скорость не менее 10 Мбит/с. Также попробуйте перезагрузить роутер и закрыть лишние вкладки в браузере."],
    ["doc_35", "Технические проблемы", "Приветствуем! Спасибо, что обратились к нам. Мобильное приложение доступно для iOS и Android. Для установки перейдите в App Store или Google Play. Если приложение вылетает, попробуйте обновить его до последней версии или переустановить."],
    ["doc_36", "Технические проблемы", "Здравствуйте! Благодарим за обращение. Ошибка 404 означает, что страница не найдена. Попробуйте обновить страницу через 5 минут или вернитесь на главную страницу. Если ошибка повторяется, сообщите нам ссылку, на которую вы пытались перейти."],
    ["doc_37", "Технические проблемы", "Добрый день! Спасибо за ваш вопрос. Если тест не загружается, проверьте ваше интернет-соединение и попробуйте перезагрузить страницу. Если это не помогло, попробуйте использовать другой браузер или устройство. Мы уже работаем над стабильностью платформы."],
    ["doc_38", "Технические проблемы", "Здравствуйте! Мы получили ваше сообщение. Белый экран после входа обычно связан с кэшем браузера. Очистите кэш и куки или попробуйте зайти в режиме инкогнито. Также обновите браузер до последней версии. Если не поможет, свяжитесь с нами снова."],
    ["doc_39", "Технические проблемы", "Приветствуем! Спасибо за обращение. Уведомления не приходят из-за настроек вашего устройства или браузера. Проверьте, разрешены ли уведомления для нашего сайта. Также проверьте папку 'Спам' в вашей почте. Мы отправили тестовое письмо, проверьте его."],
    ["doc_40", "Технические проблемы", "Добрый день! Благодарим за вопрос. Для работы платформы требуется JavaScript. Проверьте, включён ли он в вашем браузере. Также отключите VPN, если он используется — иногда он блокирует загрузку контента. Если проблема сохраняется, напишите нам."],
]

# %%
queries = [
    ["q_1", "Уважаемая поддержка. Письмо для сброса пароля не приходит уже час. Проверил спам — пусто.", "doc_2|doc_6|doc_7"],
    ["q_2", "Здравствуйте. Не могу войти в личный кабинет, пишет неверный пароль. Помогите восстановить доступ.", "doc_1|doc_2|doc_5"],
    ["q_3", "Не получается зайти в аккаунт, пароль не подходит хотя всё правильно ввожу.", "doc_1|doc_5|doc_8"],
    ["q_4", "Привет! забыл пароль что делать подскажите", "doc_1|doc_3|doc_6"],
    ["q_5", "Добрый день. Сменил пароль, теперь вообще не заходит в кабинет. Прошу помощи.", "doc_2|doc_5|doc_7"],
    ["q_6", "Восстановил пароль по ссылке из письма, но ссылка говорит что истекла. Что делать?", "doc_3|doc_4|doc_6"],
    ["q_7", "я не помню логин вообще куда нажимать", "doc_1|doc_4|doc_8"],
    ["q_8", "Уважаемая техподдержка. Аккаунт заблокировали после трёх неудачных попыток входа. Разблокируйте, пожалуйста.", "doc_4|doc_5|doc_8"],
    ["q_9", "Через сколько минут приходит письмо для сброса пароля? Жду уже 20 минут.", "doc_1|doc_2|doc_7"],
    ["q_10", "немогу зайти потму что пишет ошибка доступа", "doc_1|doc_4|doc_5"],
    
    ["q_11", "Уважаемые. Оплатил обучение картой, деньги списали, а курс не открылся. Что делать?", "doc_9|doc_12|doc_14"],
    ["q_12", "Добрый день. Подскажите, как оплатить через СБП?", "doc_9|doc_10|doc_15"],
    ["q_13", "Ввёл промокод, а скидка не применилась. Проверьте пожалуйста.", "doc_11|doc_13|doc_15"],
    ["q_14", "аплатил дважды верните деньги", "doc_12|doc_13|doc_16"],
    ["q_15", "Уважаемая поддержка. Оплатил дважды по ошибке. Как вернуть лишние деньги?", "doc_12|doc_13|doc_16"],
    ["q_16", "Карта отклоняется при оплате, хотя деньги на счёте есть. В чём проблема?", "doc_9|doc_13|doc_15"],
    ["q_17", "скидку студенческую дайте яж студент", "doc_10|doc_14|doc_16"],
    ["q_18", "Здравствуйте. Можно ли оплатить обучение частями или в рассрочку?", "doc_9|doc_12|doc_16"],
    ["q_19", "Через сколько времени зачисляется оплата? Прошло уже 5 часов.", "doc_14|doc_15|doc_16"],
    ["q_20", "Добрый день. Мы юридическое лицо, нужен счёт на оплату. Кто его выставляет?", "doc_9|doc_11|doc_15"],
    
    ["q_21", "Здравствуйте. Прошёл все тесты и модули, а сертификат не появился. Где его искать?", "doc_17|doc_19|doc_23"],
    ["q_22", "Уважаемая поддержка. Сертификат с отличием выдаётся автоматически или его нужно отдельно запрашивать?", "doc_18|doc_21|doc_22"],
    ["q_23", "Как скачать сертификат с телефона? Не могу найти кнопку.", "doc_17|doc_20|doc_24"],
    ["q_24", "сертифкат нескачивается с телефона помогите пж", "doc_17|doc_20|doc_24"],
    ["q_25", "Добрый вечер. В сертификате напечатали фамилию с ошибкой. Как это исправить?", "doc_21|doc_22|doc_24"],
    ["q_26", "Сертификат не открывается, пишет что файл повреждён.", "doc_17|doc_20|doc_24"],
    ["q_27", "Здравствуйте. Когда придёт бумажный сертификат? Заказывал две недели назад.", "doc_22|doc_23|doc_24"],
    ["q_28", "Чем отличается сертификат государственного образца от обычного?", "doc_18|doc_23|doc_24"],
    ["q_29", "Потерял сертификат об обучении. Можно восстановить?", "doc_17|doc_20|doc_21"],
    ["q_30", "в сертификате имя неправильно написали исправьте", "doc_21|doc_22|doc_24"],
    
    ["q_31", "Уважаемая поддержка. Загрузил домашнее задание в pdf, но оно не отображается в системе. Что делать?", "doc_25|doc_29|doc_30"],
    ["q_32", "Не могу загрузить домашнее задание, потому что сайт вылетает при выборе файла.", "doc_25|doc_29|doc_35|doc_36"],
    ["q_33", "Добрый день. Сколько проверяется домашнее задание? Уже 5 дней тишина.", "doc_26|doc_30|doc_31"],
    ["q_34", "Получил двойку за домашнее задание, но я старался. Можно пересдать?", "doc_27|doc_29|doc_32"],
    ["q_35", "Здравствуйте. Проверяющий сказал что мой файл битый, но у меня на компьютере он открывается. Как быть?", "doc_25|doc_29|doc_30"],
    ["q_36", "Куда прикреплять итоговый проект? Не вижу форму загрузки.", "doc_27|doc_28|doc_31"],
    ["q_37", "Какой объём должен быть у итогового проекта? 10 страниц хватит?", "doc_28|doc_31|doc_32"],
    ["q_38", "домашку загрузила аона несохранилась чё делать", "doc_25|doc_29|doc_30"],
    ["q_39", "Уважаемые. Куратор не проверяет домашку уже неделю. Что делать?", "doc_26|doc_30|doc_31"],
    ["q_40", "Уникальность моего проекта 68%, система не пропускает. Как повысить уникальность?", "doc_28|doc_31|doc_32"],
    
    ["q_41", "Уважаемая поддержка. Видео лекции не загружается, крутится бесконечно. Что делать?", "doc_33|doc_34|doc_37"],
    ["q_42", "Не открывается тест, кнопка 'Начать' не нажимается.", "doc_35|doc_37|doc_38"],
    ["q_43", "Добрый день. Сайт сильно тормозит при открытии курса.", "doc_33|doc_34|doc_38"],
    ["q_44", "Приложение на телефоне вылетает при попытке открыть тест.", "doc_35|doc_36|doc_39"],
    ["q_45", "видео негрузицо ваще белыйэкран", "doc_33|doc_34|doc_37"],
    ["q_46", "Здравствуйте. Пишет ошибка 404 при переходе на страницу курса.", "doc_36|doc_37|doc_39"],
    ["q_47", "Звука нет в лекции, хотя на других сайтах всё работает.", "doc_33|doc_34|doc_40"],
    ["q_48", "Уважаемые. Белый экран после входа в личный кабинет. Что делать?", "doc_34|doc_38|doc_40"],
    ["q_49", "Браузер говорит что версия устарела, но я обновлял его на днях.", "doc_33|doc_37|doc_40"],
    ["q_50", "уведомления неприходят на почту чё сделать", "doc_34|doc_39|doc_40"],
    
    ["q_51", "Уважаемая поддержка. Оплатил курс, деньги списали, но в личный кабинет не могу войти — пароль не подходит.", "doc_1|doc_5|doc_9|doc_12"],
    ["q_52", "Прошёл курс, сертификат не пришёл. И ещё в одном тесте была техническая ошибка.", "doc_17|doc_19|doc_33|doc_37"],
    ["q_53", "Хочу скачать сертификат, но не могу загрузить домашнее задание для завершения курса.", "doc_17|doc_25|doc_29"],
    ["q_54", "при оплате вылетела ошибка деньги списали дважды поддержка не отвечает", "doc_9|doc_12|doc_13|doc_35"],
    ["q_55", "Уважаемые. Не могу сдать итоговый проект, потому что видео с лекцией не грузится, а там объяснение.", "doc_27|doc_28|doc_33|doc_34"],
    ["q_56", "Забыл пароль, восстановил, но сертификат из личного кабинета пропал после смены пароля.", "doc_1|doc_2|doc_17|doc_20"],
    ["q_57", "Купил курс со скидкой по промокоду, но после оплаты скидка пропала и доступ не открылся.", "doc_9|doc_11|doc_13|doc_15"],
    ["q_58", "Здравствуйте. Не могу загрузить домашнее задание и видео тоже не грузится. Что за проблемы?", "doc_25|doc_29|doc_33|doc_34"],
    ["q_59", "Добрый день. Оплатил подписку на год, но доступ к курсам закрыли через месяц. Где мои деньги?", "doc_9|doc_12|doc_14|doc_16"],
    ["q_60", "Потерял доступ к почте, на которую регистрировался. Как восстановить аккаунт?", "doc_1|doc_2|doc_4|doc_7"],
    
    ["q_61", "Уважаемая поддержка. Ссылка для восстановления пароля пришла, но когда нажимаю на неё — пишет 'недействительная ссылка'.", "doc_3|doc_4|doc_7"],
    ["q_62", "Сколько попыток ввода пароля даётся до блокировки?", "doc_1|doc_4|doc_5"],
    ["q_63", "Поменял почту в профиле, теперь не могу войти со старыми данными.", "doc_2|doc_5|doc_6"],
    ["q_64", "привет подскажите как зайти если забыл пороль", "doc_1|doc_2|doc_3"],
    ["q_65", "Добрый вечер. Не приходит письмо для подтверждения смены пароля.", "doc_2|doc_6|doc_7"],
    ["q_66", "Уважаемые. При попытке оплаты пишет 'транзакция отклонена банком'. Банк говорит что всё ок.", "doc_9|doc_13|doc_15"],
    ["q_67", "Как получить чек об оплате за прошлый месяц? В личном кабинете не вижу истории.", "doc_12|doc_14|doc_16"],
    ["q_68", "Можно ли оплатить курс в рассрочку на 3 месяца без процентов?", "doc_9|doc_12|doc_16"],
    ["q_69", "промокод неработает чё сделать", "doc_11|doc_13|doc_15"],
    ["q_70", "Здравствуйте. Сколько действует электронный сертификат? Он не сгорает через год?", "doc_17|doc_20|doc_24"],
    
    ["q_71", "Можно ли заказать бумажный сертификат с доставкой за границу?", "doc_22|doc_23|doc_24"],
    ["q_72", "В сертификате указана старая должность. Как обновить данные?", "doc_21|doc_22|doc_24"],
    ["q_73", "Какие форматы файлов принимаются для домашнего задания?", "doc_25|doc_29|doc_30"],
    ["q_74", "Куратор сказал что плагиат — 50%. Как переделать проект?", "doc_27|doc_28|doc_32"],
    ["q_75", "Можно ли загрузить домашнее задание после дедлайна?", "doc_26|doc_27|doc_31"],
    ["q_76", "Уважаемая поддержка. Домашку проверили не засчитали почему?", "doc_26|doc_30|doc_31"],
    ["q_77", "Сколько дней проверяется итоговый проект?", "doc_26|doc_28|doc_30"],
    ["q_78", "невижу форму для загрузки проекта где она", "doc_27|doc_28|doc_31"],
    ["q_79", "Здравствуйте. Преподаватель сказал что файл не открывается, а у меня всё работает.", "doc_25|doc_29|doc_30"],
    ["q_80", "Добрый день. Как узнать оценку за домашнее задание?", "doc_26|doc_30|doc_31"],
    
    ["q_81", "Видео грузится очень долго, даже при хорошем интернете.", "doc_33|doc_34|doc_37"],
    ["q_82", "При попытке загрузить файл пишет 'превышен максимальный размер'. А файл всего 10 МБ.", "doc_35|doc_36|doc_38"],
    ["q_83", "Уважаемая поддержка. Уведомления от платформы не приходят на почту. Хотя в настройках всё включено.", "doc_34|doc_39|doc_40"],
    ["q_84", "Мобильное приложение не открывает курс, вылетает на главном экране.", "doc_35|doc_36|doc_39"],
    ["q_85", "приложение вылетает когда открываю тест помогите", "doc_35|doc_36|doc_37"],
    ["q_86", "Здравствуйте. Не работает кнопка 'Сохранить' в настройках профиля.", "doc_35|doc_38|doc_40"],
    ["q_87", "После обновления страницы пропал весь прогресс по курсу.", "doc_33|doc_37|doc_38"],
    ["q_88", "Добрый вечер. Чат с куратором не открывается, пишет ошибка соединения.", "doc_35|doc_39|doc_40"],
    ["q_89", "Не могу войти через мобильное приложение, хотя через браузер заходит.", "doc_1|doc_35|doc_38"],
    ["q_90", "Уважаемые. Ваш сайт очень медленно работает, невозможно учиться.", "doc_33|doc_34|doc_38"],
    
    ["q_91", "Срочно! Восстановите доступ!", "doc_1|doc_2|doc_4"],
    ["q_92", "Где сертификат?", "doc_17|doc_19|doc_23"],
    ["q_93", "Верните деньги.", "doc_12|doc_13|doc_16"],
    ["q_94", "Не открывается тест.", "doc_35|doc_37|doc_38"],
    ["q_95", "Почему нет ответа от куратора?", "doc_26|doc_30|doc_31"],
    ["q_96", "Домашку завалил, дайте пересдать.", "doc_27|doc_29|doc_32"],
    ["q_97", "Когда придёт письмо?", "doc_2|doc_6|doc_7"],
    ["q_98", "Не вижу оплаченный курс.", "doc_9|doc_12|doc_14"],
    ["q_99", "Видео не работает.", "doc_33|doc_34|doc_37"],
    ["q_100", "Пароль не меняется.", "doc_6|doc_7|doc_8"],
    
    ["q_101", "немогу вайти пароль непаходит", "doc_1|doc_3|doc_5"],
    ["q_102", "скидка непраменилась прамакод неработает", "doc_11|doc_13|doc_15"],
    ["q_103", "сертифкат нетащица чоделать", "doc_17|doc_20|doc_24"],
    ["q_104", "домашку загрузил ане паказавает", "doc_25|doc_29|doc_30"],
    ["q_105", "видео негрузицо памагите", "doc_33|doc_34|doc_37"],
    ["q_106", "куратор малчит неделю", "doc_26|doc_30|doc_31"],
    ["q_107", "сылка длясброса истела", "doc_3|doc_4|doc_7"],
    ["q_108", "дважды списали деньги верните", "doc_12|doc_13|doc_16"],
    ["q_109", "приложение вылетает памагити", "doc_35|doc_36|doc_39"],
    ["q_110", "незаходит вкабинет ваще", "doc_1|doc_4|doc_5"],
    
    ["q_111", "через сбп неплатится ошибка", "doc_9|doc_10|doc_15"],
    ["q_112", "проект неприняли чёнить сделайте", "doc_27|doc_28|doc_32"],
    ["q_113", "бд пдржк н адн сбщ нт", "doc_26|doc_30|doc_31"],
    ["q_114", "почта пдтв н прхдт", "doc_2|doc_6|doc_7"],
    ["q_115", "аплату нивижу курс закрыт", "doc_9|doc_12|doc_14"],
    ["q_116", "скока ждать сертификат", "doc_17|doc_19|doc_23"],
    ["q_117", "пароль несбрасывается ссылка неприходит", "doc_2|doc_6|doc_7"],
    ["q_118", "двойку паставили можно пересдать", "doc_27|doc_29|doc_32"],
    ["q_119", "белыйэкран после входа чёделать", "doc_34|doc_38|doc_40"],
    ["q_120", "тест незагружается помогите", "doc_35|doc_37|doc_38"],
    
    ["q_121", "ошибка404 курс пропал", "doc_36|doc_37|doc_39"],
    ["q_122", "звуканет в лекции исправте", "doc_33|doc_34|doc_40"],
    ["q_123", "ноутификации неприходят на почту", "doc_34|doc_39|doc_40"],
    ["q_124", "через сколько проверят домашку устал ждать", "doc_26|doc_30|doc_31"],
    ["q_125", "скидку студенческую немогу получить", "doc_10|doc_14|doc_16"],
    ["q_126", "фамилию в сертификате исправьте пж", "doc_21|doc_22|doc_24"],
    ["q_127", "файл неприкрепляется формат неподдерживает", "doc_25|doc_29|doc_30"],
    ["q_128", "курс оплатил адоступа нет", "doc_9|doc_12|doc_14"],
    ["q_129", "сайт виснет ваще не открывается", "doc_33|doc_34|doc_38"],
    ["q_130", "пароль неподходит хотя я егопомню", "doc_1|doc_5|doc_8"],
    
    ["q_131", "Уважаемая поддержка. Подскажите, можно ли войти в аккаунт через Google или соцсети?", "doc_2|doc_6|doc_8"],
    ["q_132", "Здравствуйте. Как привязать телефон для двухфакторной аутентификации?", "doc_1|doc_7|doc_8"],
    ["q_133", "Добрый день. Сколько стоит продление доступа после окончания курса?", "doc_14|doc_16|doc_9"],
    ["q_134", "Уважаемые. Не могу найти кнопку для отмены автопродления подписки.", "doc_16|doc_14|doc_9"],
    ["q_135", "Здравствуйте. Можно ли получить налоговый вычет за обучение?", "doc_12|doc_14|doc_16"],
    ["q_136", "Добрый вечер. Как связаться с методистом по поводу программы курса?", "doc_26|doc_31|doc_30"],
    ["q_137", "Уважаемая поддержка. В личном кабинете пропал раздел с моими курсами.", "doc_1|doc_17|doc_19"],
    ["q_138", "Здравствуйте. Сколько времени хранятся мои данные после удаления аккаунта?", "doc_1|doc_8|doc_4"],
    ["q_139", "Добрый день. Как изменить тариф с базового на премиум?", "doc_16|doc_14|doc_9"],
    ["q_140", "Уважаемые. Есть ли возможность обучаться офлайн с сохранением прогресса?", "doc_33|doc_35|doc_38"],
    
    ["q_141", "привет! не могу зайти вообще, пароль не подходит, помогите", "doc_1|doc_2|doc_5"],
    ["q_142", "добрый день! оплатил картой, деньги списали, а курс не работает, что за дела?", "doc_9|doc_12|doc_14"],
    ["q_143", "куда пропал сертификат, был же в кабинете, теперь нет", "doc_17|doc_19|doc_23"],
    ["q_144", "слушайте, домашку залил, а проверять никто не собирается?", "doc_26|doc_30|doc_31"],
    ["q_145", "ребята, видео виснет на середине, уже третий раз перезагружаю", "doc_33|doc_34|doc_37"],
    ["q_146", "подскажите, пароль сбросил, письмо пришло, а ссылка не работает", "doc_3|doc_4|doc_6"],
    ["q_147", "друзья, оплата не проходит, карта новая, деньги есть", "doc_9|doc_13|doc_15"],
    ["q_148", "народ, а сертификат с отличием автоматом дают или писать куда-то?", "doc_18|doc_21|doc_22"],
    ["q_149", "коллеги, подскажите, проект приняли, а балл низкий, можно апелляцию?", "doc_27|doc_29|doc_32"],
    ["q_150", "добрый день! кнопка сохранить не работает в настройках, что делать?", "doc_35|doc_38|doc_40"],
]

# %% [markdown]
# ## Сохранение датасетов и предварительная статистика

# %%
import csv
import os
os.makedirs('../data', exist_ok=True)
with open('../data/documents.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['doc_id', 'topic', 'response_text'])
    writer.writerows(documents)

with open('../data/queries.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['q_id', 'query_text', 'relevant_docs'])
    writer.writerows(queries)

print("Файлы сохранены в папку data")
print(f"В файле с документами {len(documents)} записей")
print(f"В файле с запросами {len(queries)} записей")
# Out:
# Файлы сохранены в папку data
# В файле с документами 40 записей
# В файле с запросами 150 записей

# %%
import pandas as pd
from IPython.display import display, Markdown
df_docs = pd.read_csv('../data/documents.csv')
df_queries = pd.read_csv('../data/queries.csv')
with pd.option_context('display.max_colwidth', None):
    display(Markdown(f"### Примеры ответов"))
    display(df_docs.sample(n=5))
    display(Markdown(f"### Примеры запросов"))
    display(df_queries.sample(n=5))
# Out:
# ### Примеры ответов
#     doc_id                 topic  \
# 6    doc_7           Авторизация
# 5    doc_6           Авторизация
# 33  doc_34  Технические проблемы
# 3    doc_4           Авторизация
# 23  doc_24            Сертификат
#
#                                                                                                                                                                                                                                                        response_text
# 6            Приветствуем! Рады вашему обращению. Если вы не получаете письмо для сброса пароля, добавьте наш домен в белый список вашего почтового ящика. Также проверьте папку 'Спам' и 'Рассылки'. В крайнем случае, свяжитесь с нами через форму обратной связи.
# ...

# %%
display(Markdown("# Статистика по ответам"))

df_docs['char_count'] = df_docs['response_text'].apply(lambda x: len(str(x)))

length_stats_docs = pd.DataFrame({
    'Показатель': ['Максимальная', 'Минимальная', 'Средняя'],
    'Количество символов': [
        df_docs['char_count'].max(),
        df_docs['char_count'].min(),
        round(df_docs['char_count'].mean(), 1)
    ]
})
display(length_stats_docs)
display(Markdown("Поскольку ответы техподдержки и так достаточно короткие (средняя длина окло 240 символов) - чанкинг здесь не требуется."))

display(Markdown("## Распределение ответов по темам"))

topic_stats = df_docs['topic'].value_counts().reset_index()
topic_stats.columns = ['Тема', 'Количество ответов']
display(topic_stats)
display(Markdown("Распределение ответов по темам равномерно (по 8 на каждую).\n\n"
                 "Это полезно для разделения смысла ответов и распределения вопрос-ответ логичным образом."))
# Out:
# # Статистика по ответам
#      Показатель  Количество символов
# 0  Максимальная                260.0
# 1   Минимальная                222.0
# 2       Средняя                240.8
# Поскольку ответы техподдержки и так достаточно короткие (средняя длина окло 240 символов) - чанкинг здесь не требуется.
# ## Распределение ответов по темам
#                    Тема  Количество ответов
# 0           Авторизация                   8
# 1                Оплата                   8
# 2            Сертификат                   8
# 3      Домашнее задание                   8
# 4  Технические проблемы                   8
# Распределение ответов по темам равномерно (по 8 на каждую).
#
# Это полезно для разделения смысла ответов и распределения вопрос-ответ логичным образом.

# %%
import re
from collections import Counter
display(Markdown("# Статистика по запросам"))
df_queries['char_count'] = df_queries['query_text'].apply(lambda x: len(str(x)))
df_queries['word_count'] = df_queries['query_text'].apply(lambda x: len(str(x).split()))

basic_stats = pd.DataFrame([{
    'Средняя длина (символов)': round(df_queries['char_count'].mean(), 1),
    'Средняя длина (слов)': round(df_queries['word_count'].mean(), 1),
    'Минимум слов в запросе': df_queries['word_count'].min(),
    'Максимум слов в запросе': df_queries['word_count'].max()
}])
display(basic_stats)

display(Markdown("## Часто встречающиеся ключевые слова"))

stop_words = {'и', 'в', 'на', 'с', 'по', 'к', 'у', 'о', 'об', 'от', 'до', 'за', 'из',
              'не', 'нет', 'был', 'была', 'было', 'были', 'этот', 'эта', 'это', 'эти',
              'весь', 'вся', 'все', 'всё', 'такой', 'такая', 'такое', 'такие',
              'который', 'которая', 'которое', 'которые', 'уже', 'еще', 'вот', 'там',
              'тут', 'здесь', 'тогда', 'потом', 'потому', 'поэтому', 'очень', 'можно',
              'нужно', 'надо', 'будет', 'будьте', 'пожалуйста', 'здравствуйте', 'добрый',
              'день', 'вечер', 'утро', 'привет', 'спасибо', 'помогите', 'подскажите',
              'скажите', 'что', 'как', 'когда', 'где', 'почему', 'зачем', 'куда',
              'через', 'для', 'после', 'сколько', 'при', 'пишет', 'хотя', 'могу', 'делать',
              'работает', 'открывается', 'уважаемая', 'уважаемые', 'поддержка'}

all_words = []
for query in df_queries['query_text']:
    cleaned = re.sub(r'[^а-яё\s]', '', str(query).lower())
    words = cleaned.split()
    for word in words:
        if len(word) > 2 and word not in stop_words:
            all_words.append(word)

word_freq = Counter(all_words)
top_words = pd.DataFrame(sorted(word_freq.most_common(25), key=lambda x: x[1], reverse=True), columns=['Ключевое слово', 'Частота'])
display(top_words)
display(Markdown("Приведены самые частые слова в запросах, которые являются основной темой запросов."))
# Out:
# # Статистика по запросам
#    Средняя длина (символов)  Средняя длина (слов)  Минимум слов в запросе  \
# 0                      56.3                   8.1                       2
#
#    Максимум слов в запросе
# 0                       17
# ## Часто встречающиеся ключевые слова
#    Ключевое слово  Частота
# 0      сертификат       16
# 1          пароль       13
# 2          деньги       11
# 3            курс       11
# 4        домашнее        8
# 5         задание        8
# 6           видео        8
# 7          ошибка        7
# 8         домашку        7
# 9          пароля        6
# 10        оплатил        6
# 11           файл        6
# 12         проект        6
# 13         письмо        5
# 14          войти        5
# 15         доступ        5
# 16         ссылка        5
# 17        списали        5
# 18      загрузить        5
# 19       вылетает        5
# 20           тест        5
# 21          курса        5
# 22     приложение        5
# ...

# %% [markdown]
# ## Создание "лишних" ответов
#
# Также создан отдельный файл с заведомо неверными ответами на предполагаемые запросы.
#
# Он необходим для оценки качетсва ответов и проверки умения отличать документы.
#
# Также увеличения количество ответов позволит сравнить скорость индексации.

# %%
import csv

noise_docs = [
    ["wrong_doc_1", "Шумный документ", "Здравствуйте! Спасибо за обращение в службу поддержки интернет-магазина. Для отслеживания заказа перейдите в раздел 'Мои заказы' в личном кабинете. Статус обновляется в течение 2 часов после отправки."],
    ["wrong_doc_2", "Шумный документ", "Добрый день! Благодарим за ваш вопрос. Возврат товара возможен в течение 14 дней после получения при условии сохранения товарного вида и упаковки. Для оформления возврата заполните форму на сайте."],
    ["wrong_doc_3", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Промокод на скидку вводится в корзине перед оформлением заказа. Скидка применяется автоматически к товарам, участвующим в акции."],
    ["wrong_doc_4", "Шумный документ", "Здравствуйте! Благодарим за обращение. Доставка осуществляется в течение 3-7 рабочих дней в зависимости от вашего региона. Трек-номер придёт на указанную почту после отправки."],
    ["wrong_doc_5", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Оплата при доставке доступна только для курьерской доставки. При самовывозе оплата производится онлайн при оформлении заказа."],
    ["wrong_doc_6", "Шумный документ", "Здравствуйте! Благодарим за обращение. Для выращивания томатов в открытом грунте рекомендуется выбирать солнечное место и регулярно поливать растения под корень. Подвязывайте кусты по мере роста."],
    ["wrong_doc_7", "Шумный документ", "Добрый день! Спасибо за вопрос. Огурцы лучше всего растут при температуре 22-25 градусов. Поливайте их тёплой водой утром или вечером, избегая попадания на листья."],
    ["wrong_doc_8", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для борьбы с тлёй на розах используйте мыльный раствор или специальные препараты. Обработку проводите в безветренную погоду."],
    ["wrong_doc_9", "Шумный документ", "Здравствуйте! Благодарим за обращение. Перегной вносят в почву осенью или весной из расчёта 5-7 кг на квадратный метр. Равномерно распределите и перекопайте."],
    ["wrong_doc_10", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Обрезку плодовых деревьев проводят ранней весной до распускания почек. Удаляйте сухие и повреждённые ветки."],
    ["wrong_doc_11", "Шумный документ", "Здравствуйте! Благодарим за обращение в службу поддержки банка. Для блокировки утерянной карты перейдите в мобильное приложение в раздел 'Карты' → 'Заблокировать'. Операция занимает 1 минуту."],
    ["wrong_doc_12", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Перевод по номеру телефона доступен в приложении круглосуточно. Комиссия отсутствует для переводов между картами нашего банка."],
    ["wrong_doc_13", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для восстановления доступа к интернет-банку используйте форму 'Забыли пароль'. Ссылка для сброса придёт на номер телефона, привязанный к карте."],
    ["wrong_doc_14", "Шумный документ", "Здравствуйте! Благодарим за обращение. Кредитная карта активируется через банкомат после получения или в приложении. Пин-код придёт отдельным письмом."],
    ["wrong_doc_15", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Проценты на остаток начисляются ежемесячно 1-го числа. Минимальная сумма для начисления — 10 000 рублей."],
    ["wrong_doc_16", "Шумный документ", "Здравствуйте! Благодарим за обращение в поддержку фитнес-приложения. Для синхронизации данных с фитнес-браслетом перейдите в настройки → 'Устройства' → 'Подключить новое устройство'."],
    ["wrong_doc_17", "Шумный документ", "Добрый день! Спасибо за вопрос. Тренировки в приложении делятся на уровни: новичок, средний, продвинутый. Рекомендуем начинать с базового уровня."],
    ["wrong_doc_18", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для отмены премиум-подписки зайдите в настройки аккаунта → 'Подписка' → 'Отменить'. Доступ сохранится до конца оплаченного периода."],
    ["wrong_doc_19", "Шумный документ", "Здравствуйте! Благодарим за обращение. Статистика по тренировкам обновляется в приложении в течение 5 минут после завершения занятия. Если данные не отображаются, попробуйте синхронизировать вручную."],
    ["wrong_doc_20", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. План питания формируется автоматически на основе ваших целей и предпочтений. Вы можете отредактировать его в разделе 'Мой план'."],
    ["wrong_doc_21", "Шумный документ", "Здравствуйте! Благодарим за обращение в службу поддержки такси. Для изменения маршрута во время поездки нажмите на адрес назначения в приложении и введите новый адрес."],
    ["wrong_doc_22", "Шумный документ", "Добрый день! Спасибо за вопрос. Отмена заказа без комиссии возможна в течение 3 минут после подтверждения. Позднее взимается штраф в размере 50 рублей."],
    ["wrong_doc_23", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для получения чека за поездку перейдите в историю поездок → выберите нужную → 'Получить чек'. Документ придёт на почту."],
    ["wrong_doc_24", "Шумный документ", "Здравствуйте! Благодарим за обращение. Оценить поездку можно в течение 24 часов после её завершения. Нажмите на звёздочки в приложении и оставьте комментарий."],
    ["wrong_doc_25", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Детский тариф доступен для поездок с детьми до 7 лет. Обязательно наличие детского кресла или бустера."],
    ["wrong_doc_26", "Шумный документ", "Здравствуйте! Благодарим за обращение. Для покраски стен водоэмульсионной краской рекомендуем предварительно загрунтовать поверхность. Это снизит расход краски до 20%."],
    ["wrong_doc_27", "Шумный документ", "Добрый день! Спасибо за вопрос. Укладку ламината начинают от дальнего угла комнаты по направлению к выходу. Обязательно оставляйте зазор 10 мм у стен."],
    ["wrong_doc_28", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для устранения засора в трубах используйте трос или специальные химические средства. Не применяйте их одновременно."],
    ["wrong_doc_29", "Шумный документ", "Здравствуйте! Благодарим за обращение. Выравнивание потолка штукатуркой возможно при перепадах до 5 см. Для больших неровностей используйте подвесные конструкции."],
    ["wrong_doc_30", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Монтаж розеток должен выполняться при отключённом электричестве. Проверьте отсутствие напряжения индикаторной отвёрткой."],
    ["wrong_doc_31", "Шумный документ", "Здравствуйте! Благодарим за обращение в службу доставки еды. Для изменения состава заказа свяжитесь с оператором в течение 5 минут после оформления."],
    ["wrong_doc_32", "Шумный документ", "Добрый день! Спасибо за вопрос. Бесплатная доставка доступна при заказе от 1000 рублей. Время доставки составляет 45-90 минут."],
    ["wrong_doc_33", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Промокод на скидку вводится в корзине перед оплатой. Комбо-предложения не суммируются с другими акциями."],
    ["wrong_doc_34", "Шумный документ", "Здравствуйте! Благодарим за обращение. Возврат заказа возможен в течение 1 часа с момента получения при сохранении целостности упаковки и продуктов."],
    ["wrong_doc_35", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Время работы доставки — с 10:00 до 23:00 ежедневно. Приём заказов заканчивается за 30 минут до закрытия."],
    ["wrong_doc_36", "Шумный документ", "Здравствуйте! Благодарим за обращение. Для изменения дат бронирования свяжитесь с нами не позднее чем за 3 дня до заезда. Изменения возможны при наличии свободных мест."],
    ["wrong_doc_37", "Шумный документ", "Добрый день! Спасибо за вопрос. Отмена бронирования без штрафа возможна за 7 дней до заезда. Позднее удерживается комиссия 15% от стоимости."],
    ["wrong_doc_38", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для получения электронного чека зайдите в личный кабинет → 'История бронирований' → 'Скачать чек'."],
    ["wrong_doc_39", "Шумный документ", "Здравствуйте! Благодарим за обращение. Требования к заселению: паспорт гражданина РФ и ваучер. Минимальный возраст гостя — 18 лет."],
    ["wrong_doc_40", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Отзывы о отеле публикуются после подтверждения бронирования. Модерация занимает до 24 часов."],
    ["wrong_doc_41", "Шумный документ", "Здравствуйте! Благодарим за обращение. Замена моторного масла рекомендуется каждые 10 000 км пробега или раз в год. Используйте масло, рекомендованное производителем."],
    ["wrong_doc_42", "Шумный документ", "Добрый день! Спасибо за вопрос. Давление в шинах проверяйте раз в месяц на холодных колёсах. Оптимальное значение указано на стойке водительской двери."],
    ["wrong_doc_43", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для продления срока службы аккумулятора избегайте глубоких разрядов и проверяйте уровень электролита раз в сезон."],
    ["wrong_doc_44", "Шумный документ", "Здравствуйте! Благодарим за обращение. Замена тормозных колодок требуется при износе более 50%. Характерный скрип при торможении указывает на необходимость замены."],
    ["wrong_doc_45", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Очистка кондиционера в автомобиле рекомендуется каждые 2 года. Это предотвращает появление неприятного запаха и распространение бактерий."],
    ["wrong_doc_46", "Шумный документ", "Здравствуйте! Благодарим за обращение на портал Госуслуг. Для подтверждения учётной записи потребуется ввести код из письма или обратиться в МФЦ с паспортом и СНИЛС."],
    ["wrong_doc_47", "Шумный документ", "Добрый день! Спасибо за вопрос. Запись на приём к врачу осуществляется в разделе 'Здравоохранение'. Выберите поликлинику, специалиста и удобное время."],
    ["wrong_doc_48", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для получения загранпаспорта нового образца потребуется загрузить фотографию и оплатить госпошлину онлайн. Срок изготовления — до 1 месяца."],
    ["wrong_doc_49", "Шумный документ", "Здравствуйте! Благодарим за обращение. Проверить начисленные штрафы ГИБДД можно в разделе 'Транспорт'. Оплатить их можно онлайн со скидкой 50% в течение 20 дней."],
    ["wrong_doc_50", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Для смены водительского удостоверения после истечения срока действия потребуется медицинская справка и оплата госпошлины. Запись на приём доступна онлайн."],
    ["wrong_doc_51", "Шумный документ", "Здравствуйте! Благодарим за обращение в службу поддержки стримингового сервиса. Для изменения качества звука перейдите в настройки воспроизведения. Доступны варианты: низкое (64 кбит/с), среднее (128 кбит/с), высокое (320 кбит/с)."],
    ["wrong_doc_52", "Шумный документ", "Добрый день! Спасибо за вопрос. Скачивание треков для офлайн-прослушивания доступно по премиум-подписке. Максимальное количество треков для скачивания — 10 000 на одно устройство."],
    ["wrong_doc_53", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для создания совместного плейлиста пригласите друга по ссылке. Оба участника должны иметь премиум-подписку."],
    ["wrong_doc_54", "Шумный документ", "Здравствуйте! Благодарим за обращение. Ребёнок случайно удалил подписку? Не переживайте, восстановить её можно в настройках аккаунта в разделе 'Семейный доступ'."],
    ["wrong_doc_55", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Рекомендации формируются на основе вашей истории прослушивания. Чтобы сбросить рекомендации, удалите историю в настройках конфиденциальности."],
    ["wrong_doc_56", "Шумный документ", "Здравствуйте! Благодарим за обращение на кулинарный портал. Для приготовления рассыпчатого риса промойте его несколько раз в холодной воде до прозрачности. Варите в соотношении 1:2 с водой."],
    ["wrong_doc_57", "Шумный документ", "Добрый день! Спасибо за вопрос. Идеальное тесто для пельменей: мука, вода, яйцо, соль. Замешивайте до эластичности, затем дайте отдохнуть 30 минут под плёнкой."],
    ["wrong_doc_58", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для сочного мяса на сковороде не прокалывайте его при жарке. Дайте мясу 'отдохнуть' 5-10 минут после приготовления."],
    ["wrong_doc_59", "Шумный документ", "Здравствуйте! Благодарим за обращение. Замена разрыхлителя: смешайте 1 чайную ложку соды и 2 чайные ложки лимонной кислоты или уксуса."],
    ["wrong_doc_60", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Для насыщенного бульона закладывайте мясо в холодную воду, для прозрачного — в кипящую."],
    ["wrong_doc_61", "Шумный документ", "Здравствуйте! Благодарим за обращение в службу поддержки социальной сети. Для восстановления доступа к странице используйте форму 'Забыли пароль'. Код восстановления придёт на привязанный номер телефона или почту."],
    ["wrong_doc_62", "Шумный документ", "Добрый день! Спасибо за вопрос. Настройки приватности позволяют скрыть список друзей, фотографии и личные данные. Изменить их можно в разделе 'Конфиденциальность'."],
    ["wrong_doc_63", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Жалоба на публикацию рассматривается в течение 24 часов. Если контент нарушает правила, он будет удалён, а автор получит предупреждение."],
    ["wrong_doc_64", "Шумный документ", "Здравствуйте! Благодарим за обращение. Уведомления о лайках и комментариях можно отключить в настройках. Зайдите в 'Уведомления' и выберите желаемый тип оповещений."],
    ["wrong_doc_65", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Архив историй доступен в профиле. Истории хранятся 24 часа, после чего автоматически перемещаются в архив. Вы можете скачать их до истечения этого срока."],
    ["wrong_doc_66", "Шумный документ", "Здравствуйте! Благодарим за обращение в службу поддержки онлайн-кинотеатра. Для смены качества видео нажмите на значок шестерёнки в плеере. Доступны варианты: 240p, 360p, 480p, 720p, 1080p."],
    ["wrong_doc_67", "Шумный документ", "Добрый день! Спасибо за вопрос. Скачивание фильмов для офлайн-просмотра доступно в мобильном приложении. Максимальное количество скачанных фильмов — 30."],
    ["wrong_doc_68", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для создания списка 'Посмотреть позже' нажмите на значок закладки под описанием фильма. Список доступен в профиле."],
    ["wrong_doc_69", "Шумный документ", "Здравствуйте! Благодарим за обращение. Детский профиль создаётся в настройках аккаунта. В нём доступен только контент с возрастным рейтингом 0+ и 6+."],
    ["wrong_doc_70", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Отменить подписку можно в настройках аккаунта или в магазине приложений (App Store/Google Play). Доступ сохранится до конца оплаченного периода."],
    ["wrong_doc_71", "Шумный документ", "Здравствуйте! Благодарим за обращение на фотопортал. Для съёмки пейзажей используйте диафрагму f/8-f/11 и выдержку, обратную фокусному расстоянию. Используйте штатив для стабильности."],
    ["wrong_doc_72", "Шумный документ", "Добрый день! Спасибо за вопрос. Портретная съёмка: используйте светосильный объектив (f/1.4-f/2.8), фокусное расстояние 50-85 мм. Размещайте модель в мягком рассеянном свете."],
    ["wrong_doc_73", "Шумный документ", "Приветствуем! Спасибо, что обратились к нам. Для обработки фото в Adobe Lightroom начните с коррекции экспозиции и баланса белого. Затем отрегулируйте контраст и насыщенность."],
    ["wrong_doc_74", "Шумный документ", "Здравствуйте! Благодарим за обращение. Фотосъёмка в дождь: защищайте камеру специальным чехлом. Ищите отражения в лужах и используйте выдержку 1/125 для заморозки капель."],
    ["wrong_doc_75", "Шумный документ", "Добрый день! Спасибо за ваш вопрос. Для резкости фото используйте выдержку не длиннее 1/60 для ручной съёмки. При недостатке света повышайте ISO, но не выше 1600 для сохранения деталей."],
]

with open('../data/extended_documents.csv', 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(['doc_id', 'topic', 'response_text'])
    writer.writerows(noise_docs)

# %%
display(Markdown("# Статистика по ответам"))

df_docs_ext = pd.read_csv('../data/extended_documents.csv')

with pd.option_context('display.max_colwidth', None):
    display(Markdown(f"### Примеры ответов не по теме"))
    display(df_docs_ext.sample(n=5))
df_docs_ext['char_count'] = df_docs_ext['response_text'].apply(lambda x: len(str(x)))

length_stats_docs = pd.DataFrame({
    'Показатель': ['Максимальная', 'Минимальная', 'Средняя'],
    'Количество символов': [
        df_docs_ext['char_count'].max(),
        df_docs_ext['char_count'].min(),
        round(df_docs_ext['char_count'].mean(), 1)
    ]
})
# Out:
# # Статистика по ответам
# ### Примеры ответов не по теме
#           doc_id            topic  \
# 68  wrong_doc_69  Шумный документ
# 55  wrong_doc_56  Шумный документ
# 71  wrong_doc_72  Шумный документ
# 69  wrong_doc_70  Шумный документ
# 20  wrong_doc_21  Шумный документ
#
#                                                                                                                                                                                     response_text
# 68                                          Здравствуйте! Благодарим за обращение. Детский профиль создаётся в настройках аккаунта. В нём доступен только контент с возрастным рейтингом 0+ и 6+.
# 55  Здравствуйте! Благодарим за обращение на кулинарный портал. Для приготовления рассыпчатого риса промойте его несколько раз в холодной воде до прозрачности. Варите в соотношении 1:2 с водой.
# ...
